# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
creditcard_data = pd.read_csv("creditcard.csv")

# %%
# first 5 rows of the dataset
creditcard_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
creditcard_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
# dataset informations
creditcard_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# checking the number of missing values in each column
creditcard_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# distribution of legal transactions & fraud transactions
creditcard_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
#  Graph: Original Imbalanced Dataset
import matplotlib.pyplot as plt

counts = creditcard_data['Class'].value_counts()

plt.figure(figsize=(6,4))
plt.bar(['Legal Transactions', 'Fraud Transactions'], counts.sort_index())

plt.title("Original Dataset Distribution")
plt.xlabel("Transaction Type")
plt.ylabel("Number of Transactions")

plt.show()

# %%
# separating the data for analysis
legal = creditcard_data[creditcard_data.Class == 0]
fraud = creditcard_data[creditcard_data.Class == 1]

# %%
print(legal.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
# statistical measures of the data
legal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
creditcard_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
from imblearn.over_sampling import SMOTE

# Separate features and target from ORIGINAL full dataset
X = creditcard_data.drop(columns=['Class', 'Time'], axis=1)
Y = creditcard_data['Class']

print("Before SMOTE:")
print(Y.value_counts())

# Apply SMOTE
smote = SMOTE(random_state=2)
X_resampled, Y_resampled = smote.fit_resample(X, Y)

print("\nAfter SMOTE:")
print(pd.Series(Y_resampled).value_counts())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from imblearn.over_sampling import SMOTE
#       3 # Separate features and target from ORIGINAL full dataset
#       4 X = creditcard_data.drop(columns=['Class', 'Time'], axis=1)
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 154733  102770.0  1.100515 -0.563634 -2.223670 -2.472525  2.928943  2.794372
# 272737  165241.0  2.179965 -1.678794 -0.234422 -1.462480 -1.912865 -0.420034
# 28385    34983.0  0.111726  1.040982 -1.732097 -0.681322  2.587268  3.428713
# 246758  153316.0 -2.057303  2.308460 -1.380008 -0.894599 -0.446775 -0.720594
# 33312    37184.0  1.181679 -0.333413 -0.186322 -0.011318  1.394107  3.949238
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 154733 -1.600320 -0.197718  0.541440  ...  1.196421  0.960131 -0.974749
# 272737 -1.660594  0.045209 -0.918552  ...  0.108026  0.823836  0.156668
# 28385  -1.062996 -1.897207 -0.858066  ... -1.418949 -0.203313 -0.084188
# 246758 -0.148827  1.222552 -0.065686  ... -0.201859 -0.558463  0.225528
# 33312  -1.286813  1.084405  0.562801  ...  0.211812  0.485058 -0.123265
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
# Graph: After SMOTE
smote_counts = pd.Series(Y_resampled).value_counts()

plt.figure(figsize=(6, 4))
plt.bar(['Legal Transactions', 'Fraud Transactions'], smote_counts.sort_index())
plt.title("Dataset Distribution After SMOTE")
plt.xlabel("Transaction Type")
plt.ylabel("Number of Transactions")
plt.show()

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      98358.739837  0.066982  0.028238  0.088165  0.049532  0.059617
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.016601 -0.017617 -0.024610 -0.011448  ... -0.006901  0.026444
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.015051  0.022731 -0.014491  0.004179  0.026459  0.022108  0.025260
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       79.119756
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
X = new_dataset.drop(columns=['Class','Time'], axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 154733  1.100515 -0.563634 -2.223670 -2.472525  2.928943  2.794372 -1.600320
# 272737  2.179965 -1.678794 -0.234422 -1.462480 -1.912865 -0.420034 -1.660594
# 28385   0.111726  1.040982 -1.732097 -0.681322  2.587268  3.428713 -1.062996
# 246758 -2.057303  2.308460 -1.380008 -0.894599 -0.446775 -0.720594 -0.148827
# 33312   1.181679 -0.333413 -0.186322 -0.011318  1.394107  3.949238 -1.286813
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 280143  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 280149 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 281144 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 281674  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
# ...

# %%
print(Y)
# Out:
# 154733    0
# 272737    0
# 28385     0
# 246758    0
# 33312     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 29) (787, 29) (197, 29)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = LogisticRegression(max_iter=1000)
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import accuracy_score

X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(Y_test, X_test_prediction)

print('Logistic Regression Accuracy : ', test_data_accuracy)
# Out:
# Logistic Regression Accuracy :  0.9390862944162437

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report

rf_model = RandomForestClassifier(n_estimators=100, random_state=2)
rf_model.fit(X_train, Y_train)

rf_predictions = rf_model.predict(X_test)

rf_accuracy = accuracy_score(Y_test, rf_predictions)
print("Random Forest Accuracy:", rf_accuracy)
# Out:
# Random Forest Accuracy: 0.9086294416243654

# %%
print("Confusion Matrix:")
print(confusion_matrix(Y_test, rf_predictions))
# Out:
# Confusion Matrix:
# [[93  6]
#  [12 86]]

# %%
print("Classification Report:")
print(classification_report(Y_test, rf_predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91        99
#            1       0.93      0.88      0.91        98
#
#     accuracy                           0.91       197
#    macro avg       0.91      0.91      0.91       197
# weighted avg       0.91      0.91      0.91       197

# %%
from xgboost import XGBClassifier

# Create model
xgb_model = XGBClassifier(eval_metric='logloss')

# Train
xgb_model.fit(X_train, Y_train)

# Predict
xgb_predictions = xgb_model.predict(X_test)

# Accuracy
xgb_accuracy = accuracy_score(Y_test, xgb_predictions)
print("XGBoost Accuracy:", xgb_accuracy)
# Out:
# XGBoost Accuracy: 0.9137055837563451

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# Build ANN Model
ann_model = Sequential([
    Dense(64, activation='relu', input_dim=X_train.shape[1]),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')   # Binary output: fraud or not
])

ann_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Early stopping to prevent overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train
ann_model.fit(X_train, Y_train,
              epochs=50,
              batch_size=32,
              validation_split=0.1,
              callbacks=[early_stop],
              verbose=1)

# %%
print("Confusion Matrix:")
print(confusion_matrix(Y_test, xgb_predictions))
# Out:
# Confusion Matrix:
# [[92  7]
#  [10 88]]

# %%
print("Classification Report:")
print(classification_report(Y_test, xgb_predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.92        99
#            1       0.93      0.90      0.91        98
#
#     accuracy                           0.91       197
#    macro avg       0.91      0.91      0.91       197
# weighted avg       0.91      0.91      0.91       197

# %%
print("\nModel Comparison:")
print("Logistic Regression Accuracy :", test_data_accuracy)
print("Random Forest Accuracy       :", rf_accuracy)
print("XGBoost Accuracy             :", xgb_accuracy)
# Out:
# Model Comparison:
# Logistic Regression Accuracy : 0.9390862944162437
# Random Forest Accuracy       : 0.9086294416243654
# XGBoost Accuracy             : 0.9137055837563451

# %%
import matplotlib.pyplot as plt

# Store model names and their accuracies
models = ['Logistic Regression', 'Random Forest', 'XGBoost']
accuracies = [test_data_accuracy, rf_accuracy, xgb_accuracy]

# Create bar chart
plt.figure(figsize=(7,5))
plt.bar(models, accuracies)

# Labels and title
plt.title("Model Accuracy Comparison")
plt.xlabel("Machine Learning Models")
plt.ylabel("Accuracy Score")

# Show accuracy values on top of bars
for i in range(len(models)):
    plt.text(i, accuracies[i], f"{accuracies[i]:.4f}", ha='center', va='bottom')

plt.show()

# %%
def predict_transaction(input_data):

    # Convert input into DataFrame with correct feature names
    input_df = pd.DataFrame([input_data], columns=X.columns)

    # Apply scaler
    input_scaled = scaler.transform(input_df)

    # Predict
    prediction = rf_model.predict(input_scaled)

    if prediction[0] == 1:
        print("⚠️ Fraud Transaction Detected!")
    else:
        print("✅ Legitimate Transaction")

# %%
# 👇 ENTER VALUES HERE
sample_transaction = [
    -1.359807, -0.072781, 2.536346, 1.378155, -0.338321,
     0.462388, 0.239599, 0.098698, 0.363787, 0.090794,
    -0.551600, -0.617801, -0.791390, -0.311169, 1.468177,
    -0.470401, 0.207971, 0.025791, 0.403993, 0.251412,
    -0.018307, 0.6789654, -0.110474, 0.066928, 0.128539,
    -0.189115, 0.133558, -0.021053,
    149.62
]

# %%
# Take any row from dataset (excluding Class column)
test_row = creditcard_data.drop(['Class','Time'], axis=1).iloc[10].values.tolist()


predict_transaction(test_row)
# Out:
# ✅ Legitimate Transaction

# %%
# Create fraud-only dataset again
fraud_data = creditcard_data[creditcard_data['Class'] == 1]
for i in range(2):
    fraud_values = fraud_data.drop(['Class','Time'], axis=1).iloc[i].values.tolist()

    print(f"\nTesting Fraud Case {i+1}")
    predict_transaction(fraud_values)
# Out:
# Testing Fraud Case 1
# ⚠️ Fraud Transaction Detected!
#
# Testing Fraud Case 2
# ⚠️ Fraud Transaction Detected!

# %%
import joblib

joblib.dump(model, "logistic_model.pkl")
joblib.dump(rf_model, "rf_model.pkl")
joblib.dump(xgb_model, "xgb_model.pkl")
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']
